# %% [markdown]
# <a href="https://colab.research.google.com/github/nonecanseeus/2023--2/blob/main/1124%20requests_gradio_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import libraries

# %%
# 파일 데이터는 엑셀 데이터다

# %%
# !pip install gradio
import gradio as gr
import requests
import pandas as pd

# !pip install xmltodict
import json
import xmltodict
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 50.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 13.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.7/302.7 kB 36.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 20.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 35.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 63.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## test API
# 국토교통부_아파트매매 실거래자료
# https://www.data.go.kr/data/15058747/openapi.do

# %%
LAWD_CD = '11290' # 법정동코드 (e.g. 성북구)
DEAL_YMD = '202310' # 조회월
serviceKey = requests.utils.unquote('miH%2BZXg85lQy4%2FkmhffvygXDIFiTwisriSLxtyECSzw6hxTVK7yI8QKIOc7mP7LEqCnhBGuj6iW1gZW65dum7A%3D%3D')

url = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade'
params ={'serviceKey' : serviceKey, 'LAWD_CD' : LAWD_CD, 'DEAL_YMD' : DEAL_YMD }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><\xea\xb1\xb0\xeb\x9e\x98\xea\xb8\x88\xec\x95\xa1>      23,500</\xea\xb1\xb0\xeb\x9e\x98\xea\xb8\x88\xec\x95\xa1><\xea\xb1\xb0\xeb\x9e\x98\xec\x9c\xa0\xed\x98\x95>\xec\xa4\x91\xea\xb0\x9c\xea\xb1\xb0\xeb\x9e\x98</\xea\xb1\xb0\xeb\x9e\x98\xec\x9c\xa0\xed\x98\x95><\xea\xb1\xb4\xec\xb6\x95\xeb\x85\x84\xeb\x8f\x84>1971</\xea\xb1\xb4\xec\xb6\x95\xeb\x85\x84\xeb\x8f\x84><\xeb\x85\x84>2023</\xeb\x85\x84><\xeb\x93\xb1\xea\xb8\xb0\xec\x9d\xbc\xec\x9e\x90>23.10.20</\xeb\x93\xb1\xea\xb8\xb0\xec\x9d\xbc\xec\x9e\x90><\xeb\xb2\x95\xec\xa0\x95\xeb\x8f\x99> \xec\x84\xb1\xeb\xb6\x81\xeb\x8f\x99</\xeb\xb2\x95\xec\xa0\x95\xeb\x8f\x99><\xec\x95\x84\xed\x8c\x8c\xed\x8a\xb8>\xec\x84\xb1\xeb\xb6\x81</\xec\x95\x84\xed\x8c\x8c\xed\x8a\xb8><\xec\x9b\x94>10</\xec\x9b\x94><\xec\x9d\xbc>14</\xec\x9d\xbc><\xec\xa0\x84\xec\x9a\xa9\xeb\xa9\xb4\xec\xa
# ...

# %% [markdown]
# https://codebeautify.org/

# %% [markdown]
# #### xmltodict: xml text to dict
# #### json.loads: json text to dict
# #### json.dumps: dict to json text

# %%
dict_data = xmltodict.parse(response.text)
# json_txt = json.dumps(dict_data, ensure_ascii = False)
# dict_data = json.loads(json_txt)

# %%
dict_data['response']['body']['items']['item']
# 우리는 body만 있으면 됨. -> item만 있으면 됨 -> item 밑의 리스트만 필요하니까... 해서 나오는 과정.
# list의 item이 dict가 여러 개 들어있고 하나의 dict는 아파트 하나라고 생각하면 됨. -> df로 만들 수 있음.(데이터프레임)
# Out:
# [{'거래금액': '23,500',
#   '거래유형': '중개거래',
#   '건축년도': '1971',
#   '년': '2023',
#   '등기일자': '23.10.20',
#   '법정동': '성북동',
#   '아파트': '성북',
#   '월': '10',
#   '일': '14',
#   '전용면적': '37.36',
#   '중개사소재지': '서울 성북구',
#   '지번': '348-3',
#   '지역코드': '11290',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '74,300',
#   '거래유형': '중개거래',
#   '건축년도': '2004',
#   '년': '2023',
#   '등기일자': None,
#   '법정동': '돈암동',
#   '아파트': '이수브라운스톤돈암',
#   '월': '10',
#   '일': '3',
#   '전용면적': '59.99',
#   '중개사소재지': '서울 성북구',
#   '지번': '636',
#   '지역코드': '11290',
#   '층': '10',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '54,700',
#   '거래유형': '중개거래',
#   '건축년도': '1994',
#   '년': '2023',
#   '등기일자': None,
#   '법정동': '돈암동',
#   '아파트': '동소문현대',
#   '월': '10',
#   '일': '5',
#   '전용면적': '84.72',
#   '중개사소재지': '서울 성북구',
#   '지번': '630',
#   '지역코드': '11290',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '79,000',
#   '거래유형': '중개거래',
#   '건축년도': '2003',
#   '년': '2023',
# ...

# %%
item = dict_data['response']['body']['items']['item']

# %%
df = pd.DataFrame(item)
df
# Out:
#        거래금액  거래유형  건축년도     년      등기일자  법정동        아파트   월   일   전용면적  \
# 0    23,500  중개거래  1971  2023  23.10.20  성북동         성북  10  14  37.36
# 1    74,300  중개거래  2004  2023      None  돈암동  이수브라운스톤돈암  10   3  59.99
# 2    54,700  중개거래  1994  2023      None  돈암동      동소문현대  10   5  84.72
# 3    79,000  중개거래  2003  2023  23.10.25  돈암동     동부센트레빌  10   7  80.54
# 4    70,400  중개거래  1999  2023      None  돈암동      돈암동삼성  10   7  84.59
# ..      ...   ...   ...   ...       ...  ...        ...  ..  ..    ...
# 122  84,000  중개거래  2019  2023      None  석관동    래미안아트리치  10  21  59.98
# 123  60,000  중개거래  1998  2023      None  석관동         두산  10  22  59.97
# 124  79,000  중개거래  2019  2023      None  석관동    래미안아트리치  10  27  59.98
# 125  49,500  중개거래  1994  2023  23.11.17  석관동      중앙하이츠  10  28  59.79
# 126  78,000  중개거래  1998  2023      None  석관동         두산  10  28   84.9
#
#              중개사소재지     지번   지역코드   층 해제사유발생일  해제여부
# 0            서울 성북구  348-3  11290   5    None  None
# ...

# %% [markdown]
# ## make a function

# %%
def test(LAWD_CD, DEAL_YMD):
  serviceKey = requests.utils.unquote('miH%2BZXg85lQy4%2FkmhffvygXDIFiTwisriSLxtyECSzw6hxTVK7yI8QKIOc7mP7LEqCnhBGuj6iW1gZW65dum7A%3D%3D')
  url = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade'
  params ={'serviceKey' : serviceKey, 'LAWD_CD' : LAWD_CD, 'DEAL_YMD' : DEAL_YMD }

  response = requests.get(url, params=params)
  dict_data = xmltodict.parse(response.content)
  item = dict_data['response']['body']['items']['item']

  df = pd.DataFrame(item)
  return df

# %% [markdown]
# ## Build a demo

# %%
demo = gr.Interface(fn=test, inputs=["text", "text"], outputs="dataframe")
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://b20a5a8b181aa825af.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b20a5a8b181aa825af.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
